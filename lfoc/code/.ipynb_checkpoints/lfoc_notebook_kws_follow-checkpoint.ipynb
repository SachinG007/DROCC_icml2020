# %%
from __future__ import print_function
import os
from random import sample
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
import pdb
from utils import *
from dataset import *
from models import *
from train_lfoc import *

# %%
class Args:
    def __init__(self):
        self.batch_size = 128
        self.epochs = 150
        self.hd = 64
        self.lr = 0.005
        self.mom = 0.0
        self.model_dir = './log/model'
        self.one_class_adv = 1
        self.inp_radius = 1.5
        self.inp_lamda = 0.05 #mu in paper
        self.reg = 0
        self.restore = 0
        self.optim = 0
        self.data_path = '.'

args=Args()

# %%
# settings
#Checkpoint store path
model_dir = args.model_dir
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

# %%
def load_data(path):
    path="/mnt/lfoc/follow-fpr/"
    train_data = np.load(os.path.join(path, 'train_data.npy'))
    train_lab = np.load(os.path.join(path, 'train_labels.npy'))
    test_data_norm = np.load(os.path.join(path, 'test_others_data.npy'))
    test_lab_norm = np.load(os.path.join(path, 'test_others_labels.npy'))
    test_data_close =  np.load(os.path.join(path, 'test_cn_data.npy'))
    test_lab_close =  np.load(os.path.join(path, 'test_cn_labels.npy'))
    ##preprocessing 
    mean=np.mean(train_data,0)
    #pdb.set_trace()
    std=np.std(train_data,0)
    std[std[:]<0.00001]=1
    train_data=(train_data-mean)/std
    test_data_norm=(test_data_norm-mean)/std
    test_data_close=(test_data_close-mean)/std
    train_samples = train_data.shape[0]
    test_samples_norm = test_data_norm.shape[0]
    test_samples_close = test_data_close.shape[0]
    timesteps = 98
    num_input = 32
    train_data = np.reshape(train_data, (train_samples, timesteps, num_input))
    test_data_norm = np.reshape(test_data_norm, (test_samples_norm, timesteps, num_input))
    test_data_close = np.reshape(test_data_close, (test_samples_close, timesteps, num_input))

    return train_data, train_lab, test_data_norm, test_lab_norm, test_data_close, test_lab_close

# %%
def main():

    train_data, train_lab, test_data_norm, test_lab_norm, test_data_close, test_lab_close = load_data(args.data_path)
    model = LSTM_FC(input_dim=32, num_classes=1, num_hidden_nodes=args.hd).to(device)
    model = nn.DataParallel(model)
    #Restore from checkpoint 
    if args.restore == 1:
        model.load_state_dict(torch.load(os.path.join(args.model_dir, 'model_lfoc.pt')))
        print("Saved Model Loaded")
    # Training the model
    train(args, model, device, train_data, train_lab, test_data_norm, test_lab_norm, test_data_close, test_lab_close)

# %%
main()
# Out:
# using Adam
# Epoch :  0  CE Loss :  0.7123213410377502  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  1  CE Loss :  0.6847115159034729  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  2  CE Loss :  0.6763880252838135  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  3  CE Loss :  0.6705709099769592  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  4  CE Loss :  0.6658898591995239  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  5  CE Loss :  0.6619934439659119  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  6  CE Loss :  0.6586864590644836  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  7  CE Loss :  0.6558533310890198  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  8  CE Loss :  0.653410017490387  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  9  CE Loss :  0.6512877345085144  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  10  CE Loss :  0.6494295597076416  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  11  CE Loss :  0.6477893590927124  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  12  CE Loss :  0.6463297009468079  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  13  CE Loss :  0.6450210213661194  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  14  CE Loss :  0.6438390016555786  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  15  CE Loss :  0.6427642703056335  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  16  CE Loss :  0.64178067445755  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  17  CE Loss :  0.6408753395080566  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  18  CE Loss :  0.6400376558303833  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  19  CE Loss :  0.6392586827278137  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  20  CE Loss :  0.6385312080383301  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  21  CE Loss :  0.6378492116928101  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  22  CE Loss :  0.6372073888778687  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  23  CE Loss :  0.6366016864776611  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  24  CE Loss :  0.6360283493995667  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  25  CE Loss :  0.6354841589927673  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  26  CE Loss :  0.6349664330482483  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  27  CE Loss :  0.6344729661941528  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  28  CE Loss :  0.6340014338493347  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  29  CE Loss :  0.6335504651069641  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  30  CE Loss :  0.6331180334091187  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  31  CE Loss :  0.6327029466629028  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  32  CE Loss :  0.6323039531707764  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  33  CE Loss :  0.6319197416305542  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  34  CE Loss :  0.6315494179725647  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  35  CE Loss :  0.6311920881271362  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  36  CE Loss :  0.6308467984199524  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  37  CE Loss :  0.6305128931999207  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  38  CE Loss :  0.6301897168159485  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  39  CE Loss :  0.629876434803009  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  40  CE Loss :  0.6295726299285889  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  41  CE Loss :  0.6292777061462402  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  42  CE Loss :  0.6289910674095154  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  43  CE Loss :  0.6287124156951904  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  44  CE Loss :  0.6284411549568176  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  45  CE Loss :  0.6281771063804626  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  46  CE Loss :  0.6279195547103882  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  47  CE Loss :  0.6276684403419495  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  48  CE Loss :  0.6274233460426331  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  49  CE Loss :  0.6271840333938599  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  50  CE Loss :  0.6269500851631165  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  51  CE Loss :  0.6267214417457581  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  52  CE Loss :  0.6264976859092712  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  53  CE Loss :  0.6262785792350769  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  54  CE Loss :  0.6260640621185303  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  55  CE Loss :  0.6258537769317627  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  56  CE Loss :  0.6256474852561951  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  57  CE Loss :  0.6254453063011169  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  58  CE Loss :  0.6252468228340149  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  59  CE Loss :  0.6250520348548889  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  60  CE Loss :  0.6248605847358704  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  61  CE Loss :  0.6246725916862488  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
# Epoch :  62  CE Loss :  0.624487578868866  AdvLoss@Hidden :  0.0
#  NumDetectedAdvPoints@Hidden  0.0
